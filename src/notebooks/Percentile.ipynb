# %%
import numpy as np

from deicide.loading import load_full_candidates_df

from _cacheutil import *

# %%
DB_DIR = "data/"
JD_DIR = "data-jd/"

# %%
# cdf = load_or_create("candidates", lambda: load_full_candidates_df(DB_DIR, JD_DIR))
cdf = load("candidates")

# %%
cdf
# Out:
#                   project  commit_id  \
# id
# drill-260           drill       3815
# drill-6157          drill       3815
# ignite-1135        ignite      21397
# drill-5276          drill       3815
# ignite-6893        ignite      21397
# ...                   ...        ...
# activemq-226884  activemq       9610
# activemq-244878  activemq       9610
# activemq-156409  activemq       9610
# activemq-161777  activemq       9610
# activemq-235942  activemq       9610
#
#                                                           filename    loc  \
# id
# drill-260        protocol/src/main/java/org/apache/drill/exec/p...  48864
# drill-6157       protocol/src/main/java/org/apache/drill/exec/p...  28788
# ignite-1135      modules/core/src/main/java/org/apache/ignite/i...  12177
# drill-5276       protocol/src/main/java/org/apache/drill/exec/p...  11164
# ignite-6893      modules/core/src/main/java/org/apache/ignite/s...   8141
# ...                                                            ...    ...
# activemq-226884  activemq-client/src/main/java/org/apache/activ...      0
# activemq-244878  activemq-openwire-legacy/src/main/java/org/apa...      0
# activemq-156409  activemq-openwire-legacy/src/main/java/org/apa...      0
# activemq-161777  activemq-openwire-legacy/src/main/java/org/apa...      0
# activemq-235942  activemq-client/src/main/java/org/apache/activ...      0
#
#                  members  fan_in  commits   churn  authors     loc_pct  \
# id
# drill-260            146      40       34  663202       20  100.000000
# drill-6157            97     284       88  283962       41   99.967427
# ignite-1135          679    1774      435   58538      103  100.000000
# drill-5276            46      77       28  112240       16   99.934853
# ignite-6893          113       5      380   86957       74   99.982076
# ...                  ...     ...      ...     ...      ...         ...
# activemq-226884        5       2        1       0        1    4.586241
# activemq-244878        5       2        1       0        1    4.586241
# activemq-156409        5       1        1       0        1    4.586241
# activemq-161777        5       1        1       0        1    4.586241
# activemq-235942        5       1        1       0        1    4.586241
#
#                  members_pct  fan_in_pct  commits_pct   churn_pct  \
# id
# drill-260          99.837134   95.912052    97.068404  100.000000
# drill-6157         99.641694   99.837134    99.706840   99.967427
# ignite-1135       100.000000   99.910378    99.892454   99.820756
# drill-5276         97.557003   98.110749    95.537459   99.934853
# ignite-6893        98.978312   62.197526    99.802832   99.928303
# ...                      ...         ...          ...         ...
# activemq-226884    20.014955   52.716849    27.691924    4.586241
# activemq-244878    20.014955   52.716849    27.691924    4.586241
# activemq-156409    20.014955   23.354935    27.691924    4.586241
# activemq-161777    20.014955   23.354935    27.691924    4.586241
# activemq-235942    20.014955   23.354935    27.691924    4.586241
#
#                  authors_pct  in_jdeo_data
# id
# drill-260          97.768730         False
# drill-6157         99.885993         False
# ignite-1135        99.964151         False
# drill-5276         96.384365         False
# ignite-6893        99.865567         False
# ...                      ...           ...
# activemq-226884    29.062812         False
# activemq-244878    29.062812         False
# activemq-156409    29.062812         False
# activemq-161777    29.062812         False
# activemq-235942    29.062812         False
#
# [44814 rows x 16 columns]

# %%
np.percentile(np.array(cdf["members"]), 50)
# Out:
# 7.0
