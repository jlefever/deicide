# %%
import sys
import os
from statistics import median_high

import pandas as pd

from deicide import jdeo, gri
from deicide.algorithms import akash19
from deicide.validation2 import *
from deicide.loading import load_dataset, load_full_candidates_df
from deicide.deicide import cluster_dataset
from deicide.dendrogram import dump_indicators

# %%
import warnings
warnings.simplefilter(action="ignore", category=pd.errors.PerformanceWarning)

# %%
def validate_subjects(
    subjects: pd.DataFrame, db_dir: str, jd_dir: str, results_dir: str, suffix: str
):
    if os.path.exists(results_dir):
        raise RuntimeError("the results dir '{}' already exists".format(results_dir))
    os.makedirs(results_dir)

    res = subjects.copy()
    res["my_blocks"] = ""
    res["unmatched_jd_methods"] = ""
    res["comparable_methods"] = ""
    res["comparable_commits"] = ""
    res["comparable_authors"] = ""
    res["my_comparable_clusters"] = ""
    res["jd_comparable_clusters"] = ""
    res["my_commit_sim"] = ""
    res["jd_commit_sim"] = ""
    res["ak_commit_sim"] = ""
    res["my_author_sim"] = ""
    res["jd_author_sim"] = ""
    res["ak_author_sim"] = ""

    for i, (subject_id, row) in enumerate(subjects.iterrows()):
        project = row["project"]
        filename = row["filename"]
        print("Working on Subject #{}: ({}, {})".format(i + 1, project, filename))

        # Define helper function for setting output values
        def set_cell(col_name, value):
            res.at[subject_id, col_name] = value

        # Load JD clustering
        jd_rows = jdeo.load_jdeo_subject(jd_dir, project, filename)

        # Skip if not in JD data
        if len(jd_rows) == 0:
            print("Missing from JD. Skipping...")
            continue

        # Run our clustering algorithm
        ds = load_dataset(f"{db_dir}{project}.db", filename, row["commit_id"])
        entities_df = cluster_dataset(ds)
        targets_df = entities_df[~(entities_df["kind"] == "file")]
        # entities_df.to_csv(os.path.join(results_dir, "{}.csv".format(subject_id)))
        set_cell("my_blocks", targets_df.groupby("block_name").ngroups)

        # Attempt to match JD entity data with ours
        jd_id_map = jdeo.match_entities(jd_rows, ds.targets_df)
        unmatched_jd_methods = sum(
            1 for row, id in jd_id_map.items() if id is None and row.kind == "method"
        )
        set_cell("unmatched_jd_methods", unmatched_jd_methods)

        if unmatched_jd_methods > 2:
            continue

        # Run the Akash19 clustering algorithm
        print("Running Akash19...")
        ak_clustering = akash19.akash19(akash19.to_godclass(ds), 2.0, 0)
        # ak_clusterings = akash19.many_akash19(akash19.to_godclass(ds), 8, (0.3, 0.9))

        # Create clustering objects for each kind of clustering
        my_clustering = to_my_clustering(entities_df).without_root()
        jd_clustering = to_jdeo_clustering(jd_id_map).without_root()
        commit_clustering = to_commit_clustering(ds.touches_df)
        author_clustering = to_author_clustering(ds.touches_df)

        # Get methods in common
        method_ids = set(entities_df[entities_df["kind"].isin(["method", "constructor"])].index)
        my_entity_ids = my_clustering.entities()
        jd_entity_ids = jd_clustering.entities()
        ak_entity_ids = ak_clustering.entities()
        commit_entity_ids = commit_clustering.entities()
        author_entity_ids = author_clustering.entities()
        common_method_ids = (
            method_ids
            & my_entity_ids
            & jd_entity_ids
            & ak_entity_ids
            & commit_entity_ids
            & author_entity_ids
        )

        # For debug / diagram purposes
        # client_clustering = to_client_clustering(ds.clients_df, ds.client_deps_df).subset(common_method_ids)
        my_clustering_with_files = to_my_clustering_with_files(entities_df).without_root()

        # ...
        my_subclustering = my_clustering.subset(common_method_ids)
        jd_subclustering = jd_clustering.subset(common_method_ids)
        ak_subclustering = ak_clustering.subset(common_method_ids)
        # ak_subclusterings = [c.subset(common_method_ids) for c in ak_clusterings]
        commit_subclustering = commit_clustering.subset(common_method_ids)
        author_subclustering = author_clustering.subset(common_method_ids)

        # Remove any cluster that 1) contains only a single entity AND 2) is not that entities only cluster
        my_subclustering = my_subclustering.normalize()
        jd_subclustering = jd_subclustering.normalize()
        ak_subclustering = ak_subclustering.normalize()
        # ak_subclusterings = [c.normalize() for c in ak_subclusterings]

        # Create matrices from each kind of clustering
        my_arr = my_subclustering.expand().ndarray()
        jd_arr = jd_subclustering.expand().ndarray()
        ak_arr = ak_subclustering.expand().ndarray()
        # ak_arrs = [c.expand().ndarray() for c in ak_subclusterings]
        commit_arr = commit_subclustering.ndarray()
        author_arr = author_subclustering.ndarray()

        # Record the sizes of these matrices
        set_cell("comparable_methods", len(common_method_ids))
        set_cell("comparable_commits", commit_arr.shape[0])
        set_cell("comparable_authors", author_arr.shape[0])
        set_cell("my_comparable_clusters", my_arr.shape[0])
        set_cell("jd_comparable_clusters", jd_arr.shape[0])

        # Calculate the similarities
        set_cell("my_commit_sim", gri.grand_index(my_arr, commit_arr))
        set_cell("jd_commit_sim", gri.grand_index(jd_arr, commit_arr))
        set_cell("ak_commit_sim", gri.grand_index(ak_arr, commit_arr))
        set_cell("my_author_sim", gri.grand_index(my_arr, author_arr))
        set_cell("jd_author_sim", gri.grand_index(jd_arr, author_arr))
        set_cell("ak_author_sim", gri.grand_index(ak_arr, author_arr))

        # Find best Akash19
        # ak_scores = [(i, gri.grand_index(arr, commit_arr)) for i, arr in enumerate(ak_arrs)]
        # ak_clustering_median = median_high([s for _, s in ak_scores])
        # ak_clustering_ix = min([i for i, s in ak_scores if s == ak_clustering_median])
        # # ak_clustering_ix = max(ak_scores, key=lambda x: x[1])[0]
        # ak_clustering = ak_clusterings[ak_clustering_ix]
        # ak_subclustering = ak_subclusterings[ak_clustering_ix]
        # ak_arr = ak_arrs[ak_clustering_ix]
        # set_cell("ak_commit_sim", gri.grand_index(ak_arr, commit_arr))
        # set_cell("ak_author_sim", gri.grand_index(ak_arr, author_arr))

        # Dump
        dump_indicators(
            entities_df.copy(),
            os.path.join(results_dir, f"{subject_id}.xlsx"),
            my_clx=my_clustering,
            my_clx_without_singletons=my_clustering.normalize(),
            my_clx_final=my_subclustering,
            # my_clx_with_files = my_clustering_with_files,
            jd_clx=jd_clustering,
            jd_clx_without_singletons=jd_clustering.normalize(),
            jd_clx_final=jd_subclustering,
            ak_clx=ak_clustering,
            ak_clx_without_singletons=ak_clustering.normalize(),
            ak_clx_final=ak_subclustering,
            # commit_clx=commit_clustering,
            # author_clx=author_clustering,
            # client_clx=client_clustering
        )

    print(sorted(set(res["project"])))

    # Unable to match more than two methods reported by JD to our data.
    # One cause of this is that JD will list members of nested classes as
    # members of the top level class. Wheras we only consider members
    # directly inside the top-level class.
    res = res[res["unmatched_jd_methods"] < 3]
    res["short_filename"] = [f.split("/")[-1] for f in res["filename"]]
    res.to_csv(os.path.join(results_dir, f"_summary{suffix}.csv"))

# %%
RESULTS_DIR = "results/"
DB_DIR = "data/"
JD_DIR = "data-jd/"

# %%
# Discover subjects
cdf = load_full_candidates_df(DB_DIR, JD_DIR)
subjects_df = cdf[(cdf["loc_pct"] >= 90) & (cdf["loc"] >= 500) & (cdf["commits"] >= 10) & (cdf["authors"] >= 2) & cdf["in_jdeo_data"]].copy()
# Out:
# Finding candidates in activemq.db...
# Finding candidates in calcite.db...
# Finding candidates in camel.db...
# Finding candidates in dolphinscheduler.db...
# Finding candidates in drill.db...
# Finding candidates in dubbo.db...
# Finding candidates in hudi.db...
# Finding candidates in ignite.db...
# Finding candidates in iotdb.db...
# Finding candidates in kafka.db...
# Finding candidates in linkis.db...
# Finding candidates in logging-log4j2.db...
# Finding candidates in nifi.db...
# Finding candidates in pinot.db...
# Finding candidates in pulsar.db...
# Finding candidates in shardingsphere.db...
# Finding candidates in shenyu.db...

# %%
# Drop some less important columns to produce an easier to read CSV
labels = [c for c in subjects_df.columns if c.endswith("_pct")] + ["in_jdeo_data"]
subjects_df.drop(labels, axis=1, inplace=True)

# %%
subjects_df
# Out:
#                             project  commit_id  \
# id
# pinot-11                      pinot       8576
# activemq-930               activemq       9610
# logging-log4j2-2930  logging-log4j2      10412
# activemq-8854              activemq       9610
# activemq-571               activemq       9610
# ...                             ...        ...
# activemq-55178             activemq       9610
# dubbo-11605                   dubbo       6257
# activemq-36012             activemq       9610
# logging-log4j2-8430  logging-log4j2      10412
# pinot-33322                   pinot       8576
#
#                                                               filename   loc  \
# id
# pinot-11             pinot-controller/src/main/java/org/apache/pino...  3633
# activemq-930         activemq-broker/src/main/java/org/apache/activ...  3170
# logging-log4j2-2930  log4j-api/src/main/java/org/apache/logging/log...  2848
# activemq-8854        activemq-client/src/main/java/org/apache/activ...  2548
# activemq-571         activemq-broker/src/main/java/org/apache/activ...  2377
# ...                                                                ...   ...
# activemq-55178       activemq-client/src/main/java/org/apache/activ...   510
# dubbo-11605          dubbo-common/src/main/java/org/apache/dubbo/co...   506
# activemq-36012       activemq-broker/src/main/java/org/apache/activ...   503
# logging-log4j2-8430  log4j-api/src/main/java/org/apache/logging/log...   503
# pinot-33322          pinot-segment-spi/src/main/java/org/apache/pin...   502
#
#                      members  fan_in  commits  churn  authors
# id
# pinot-11                 212     110      210  29925       49
# activemq-930             409    1082      131  15429       26
# logging-log4j2-2930      474     112      148  39592       21
# activemq-8854            275     225       60   9620       14
# activemq-571             149      43      187  16608       22
# ...                      ...     ...      ...    ...      ...
# activemq-55178            90     172       17   1564        5
# dubbo-11605              103      88       29   1922       12
# activemq-36012            85     108       23   2248       12
# logging-log4j2-8430       51      39       39   2266       15
# pinot-33322               25      22       10   3149        9
#
# [159 rows x 9 columns]

# %%
# Get the result_dir
os.makedirs(RESULTS_DIR, exist_ok=True)
result_nums = [int(n.split("-")[1]) for n in os.listdir(RESULTS_DIR) if n.startswith("results-")]
result_num = max(result_nums, default=0) + 1
result_dir = os.path.join(RESULTS_DIR, f"results-{result_num}")

# %%
validate_subjects(subjects_df, DB_DIR, JD_DIR, result_dir, f"-{result_num}")
# Out:
# Working on Subject #1: (pinot, pinot-controller/src/main/java/org/apache/pinot/controller/helix/core/PinotHelixResourceManager.java)
# [R.W0]             (00:27:52) Starting... (299 nodes)	Bisected with a cut weight of 994923.0 in 8.4846 secs.
# [R.W0.A]           (00:28:01) Starting... (196 nodes)	Bisected with a cut weight of 971977.0 in 4.7409 secs.
# [R.W0.A.A]         (00:28:06) Starting... (93 nodes)	Bisected with a cut weight of 439340.0 in 0.7237 secs.
# [R.W0.A.A.A]       (00:28:06) Starting... (36 nodes)	Bisected with a cut weight of 123794.0 in 0.2313 secs.
# [R.W0.A.A.A.A]     (00:28:07) Starting... (10 nodes)	Bisected with a cut weight of 41064.0 in 0.1722 secs.
# [R.W0.A.A.A.A.A]   (00:28:07) Starting... (7 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.A.A.B]   (00:28:07) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.A.B]     (00:28:07) Starting... (26 nodes)	Bisected with a cut weight of 79894.0 in 0.1806 secs.
# [R.W0.A.A.A.B.A]   (00:28:07) Starting... (9 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.A.B.B]   (00:28:07) Starting... (17 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B]       (00:28:07) Starting... (57 nodes)	Bisected with a cut weight of 624099.0 in 0.7309 secs.
# [R.W0.A.A.B.A]     (00:28:08) Starting... (26 nodes)	Bisected with a cut weight of 201761.0 in 0.2386 secs.
# [R.W0.A.A.B.A.A]   (00:28:08) Starting... (22 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B.A.B]   (00:28:08) Starting... (4 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B.B]     (00:28:08) Starting... (31 nodes)	Bisected with a cut weight of 406017.0 in 0.1889 secs.
# [R.W0.A.A.B.B.A]   (00:28:08) Starting... (13 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B.B.B]   (00:28:08) Starting... (18 nodes)	Bisected with a cut weight of 613471.0 in 0.1969 secs.
# [R.W0.A.A.B.B.B.A] (00:28:08) Starting... (14 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B.B.B.B] (00:28:08) Starting... (4 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B]         (00:28:08) Starting... (103 nodes)	Bisected with a cut weight of 781350.0 in 1.3621 secs.
# [R.W0.A.B.A]       (00:28:10) Starting... (71 nodes)	Bisected with a cut weight of 778886.0 in 1.8341 secs.
# [R.W0.A.B.A.A]     (00:28:12) Starting... (23 nodes)	Bisected with a cut weight of 366318.0 in 0.2070 secs.
# [R.W0.A.B.A.A.A]   (00:28:12) Starting... (9 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.A.A.B]   (00:28:12) Starting... (14 nodes)	Bisected with a cut weight of 274864.0 in 0.1855 secs.
# [R.W0.A.B.A.A.B.A] (00:28:12) Starting... (4 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.A.A.B.B] (00:28:12) Starting... (10 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.A.B]     (00:28:12) Starting... (48 nodes)	Bisected with a cut weight of 588777.0 in 0.5298 secs.
# [R.W0.A.B.A.B.A]   (00:28:13) Starting... (17 nodes)	Bisected with a cut weight of 149346.0 in 0.1895 secs.
# [R.W0.A.B.A.B.A.A] (00:28:13) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.A.B.A.B] (00:28:13) Starting... (14 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.A.B.B]   (00:28:13) Starting... (31 nodes)	Bisected with a cut weight of 500667.0 in 0.3030 secs.
# [R.W0.A.B.A.B.B.A] (00:28:13) Starting... (23 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.A.B.B.B] (00:28:13) Starting... (8 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.B]       (00:28:13) Starting... (32 nodes)	Bisected with a cut weight of 340720.0 in 0.3900 secs.
# [R.W0.A.B.B.A]     (00:28:13) Starting... (19 nodes)	Bisected with a cut weight of 298937.0 in 0.2287 secs.
# [R.W0.A.B.B.A.A]   (00:28:14) Starting... (14 nodes)	Bisected with a cut weight of 148453.0 in 0.2450 secs.
# [R.W0.A.B.B.A.A.A] (00:28:14) Starting... (4 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.B.A.A.B] (00:28:14) Starting... (10 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.B.A.B]   (00:28:14) Starting... (5 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.B.B]     (00:28:14) Starting... (13 nodes)	Bisected with a cut weight of 177652.0 in 0.2576 secs.
# [R.W0.A.B.B.B.A]   (00:28:14) Starting... (5 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.B.B.B]   (00:28:14) Starting... (8 nodes)	Aborted. Weight under threshold.
# [R.W0.B]           (00:28:14) Starting... (103 nodes)	Bisected with a cut weight of 549823.0 in 0.9931 secs.
# [R.W0.B.A]         (00:28:15) Starting... (62 nodes)	Bisected with a cut weight of 578565.0 in 1.3384 secs.
# [R.W0.B.A.A]       (00:28:17) Starting... (26 nodes)	Bisected with a cut weight of 217444.0 in 0.2917 secs.
# [R.W0.B.A.A.A]     (00:28:17) Starting... (10 nodes)	Bisected with a cut weight of 124204.0 in 0.1816 secs.
# [R.W0.B.A.A.A.A]   (00:28:17) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.A.A.B]   (00:28:17) Starting... (7 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.A.B]     (00:28:17) Starting... (16 nodes)	Bisected with a cut weight of 281476.0 in 0.2043 secs.
# [R.W0.B.A.A.B.A]   (00:28:17) Starting... (7 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.A.B.B]   (00:28:17) Starting... (9 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.B]       (00:28:17) Starting... (36 nodes)	Bisected with a cut weight of 492379.0 in 0.8936 secs.
# [R.W0.B.A.B.A]     (00:28:18) Starting... (21 nodes)	Bisected with a cut weight of 450671.0 in 1.0290 secs.
# [R.W0.B.A.B.A.A]   (00:28:19) Starting... (8 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.B.A.B]   (00:28:19) Starting... (13 nodes)	Bisected with a cut weight of 334187.0 in 0.2529 secs.
# [R.W0.B.A.B.A.B.A] (00:28:19) Starting... (8 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.B.A.B.B] (00:28:19) Starting... (5 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.B.B]     (00:28:19) Starting... (15 nodes)	Bisected with a cut weight of 383292.0 in 0.2933 secs.
# [R.W0.B.A.B.B.A]   (00:28:20) Starting... (10 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.B.B.B]   (00:28:20) Starting... (5 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B]         (00:28:20) Starting... (41 nodes)	Bisected with a cut weight of 120369.0 in 0.2936 secs.
# [R.W0.B.B.A]       (00:28:20) Starting... (23 nodes)	Bisected with a cut weight of 120123.0 in 0.1991 secs.
# [R.W0.B.B.A.A]     (00:28:20) Starting... (13 nodes)	Bisected with a cut weight of 231771.0 in 0.2497 secs.
# [R.W0.B.B.A.A.A]   (00:28:20) Starting... (5 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.A.A.B]   (00:28:20) Starting... (8 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.A.B]     (00:28:20) Starting... (10 nodes)	Bisected with a cut weight of 31289.0 in 0.1760 secs.
# [R.W0.B.B.A.B.A]   (00:28:21) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.A.B.B]   (00:28:21) Starting... (4 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.B]       (00:28:21) Starting... (18 nodes)	Bisected with a cut weight of 37033.0 in 0.1715 secs.
# [R.W0.B.B.B.A]     (00:28:21) Starting... (11 nodes)	Bisected with a cut weight of 34892.0 in 0.1657 secs.
# [R.W0.B.B.B.A.A]   (00:28:21) Starting... (5 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.B.A.B]   (00:28:21) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.B.B]     (00:28:21) Starting... (7 nodes)	Aborted. Weight under threshold.
# [R.W1]             (00:28:21) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W2]             (00:28:21) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W3]             (00:28:21) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W4]             (00:28:21) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W5]             (00:28:21) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W6]             (00:28:21) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W7]             (00:28:21) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W8]             (00:28:21) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W9]             (00:28:21) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W10]            (00:28:21) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W11]            (00:28:21) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W12]            (00:28:21) Starting... (1 nodes)	Aborted. Weight under threshold.
# Running Akash19...
# DEBUG: best_k=2
# HERE
# Working on Subject #2: (activemq, activemq-broker/src/main/java/org/apache/activemq/broker/BrokerService.java)
# [R.W0]             (00:28:57) Starting... (1391 nodes)	Bisected with a cut weight of 1141492.0 in 4.0995 secs.
# [R.W0.A]           (00:29:01) Starting... (1203 nodes)	Bisected with a cut weight of 1752292.0 in 1.2227 secs.
# [R.W0.A.A]         (00:29:02) Starting... (1092 nodes)	Bisected with a cut weight of 3510753.0 in 1.9582 secs.
# [R.W0.A.A.A]       (00:29:04) Starting... (1002 nodes)	Bisected with a cut weight of 5007628.0 in 7.5220 secs.
# [R.W0.A.A.A.A]     (00:29:12) Starting... (907 nodes)	Bisected with a cut weight of 6435069.0 in 8.4407 secs.
# [R.W0.A.A.A.A.A]   (00:29:20) Starting... (871 nodes)	Bisected with a cut weight of 6665824.0 in 3.6668 secs.
# [R.W0.A.A.A.A.A.A] (00:29:24) Starting... (241 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.A.A.A.B] (00:29:24) Starting... (630 nodes)	Bisected with a cut weight of 4790709.0 in 1.5664 secs.
# [R.W0.A.A.A.A.A.B.A] (00:29:26) Starting... (604 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.A.A.A.B.B] (00:29:26) Starting... (26 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.A.A.B]   (00:29:26) Starting... (36 nodes)	Bisected with a cut weight of 2312923.0 in 0.8535 secs.
# [R.W0.A.A.A.A.B.A] (00:29:27) Starting... (14 nodes)	Bisected with a cut weight of 1941770.0 in 0.8277 secs.
# [R.W0.A.A.A.A.B.A.A] (00:29:28) Starting... (8 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.A.A.B.A.B] (00:29:28) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.A.A.B.B] (00:29:28) Starting... (22 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.A.B]     (00:29:28) Starting... (95 nodes)	Bisected with a cut weight of 1562884.0 in 3.8611 secs.
# [R.W0.A.A.A.B.A]   (00:29:31) Starting... (66 nodes)	Bisected with a cut weight of 3440095.0 in 0.8285 secs.
# [R.W0.A.A.A.B.A.A] (00:29:32) Starting... (51 nodes)	Bisected with a cut weight of 3523547.0 in 0.8943 secs.
# [R.W0.A.A.A.B.A.A.A] (00:29:33) Starting... (22 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.A.B.A.A.B] (00:29:33) Starting... (29 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.A.B.A.B] (00:29:33) Starting... (15 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.A.B.B]   (00:29:33) Starting... (29 nodes)	Bisected with a cut weight of 452619.0 in 1.4150 secs.
# [R.W0.A.A.A.B.B.A] (00:29:35) Starting... (22 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.A.B.B.B] (00:29:35) Starting... (7 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B]       (00:29:35) Starting... (90 nodes)	Bisected with a cut weight of 1729780.0 in 1.4427 secs.
# [R.W0.A.A.B.A]     (00:29:36) Starting... (50 nodes)	Bisected with a cut weight of 1803977.0 in 1.2073 secs.
# [R.W0.A.A.B.A.A]   (00:29:37) Starting... (20 nodes)	Bisected with a cut weight of 548357.0 in 1.1220 secs.
# [R.W0.A.A.B.A.A.A] (00:29:38) Starting... (4 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B.A.A.B] (00:29:38) Starting... (16 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B.A.B]   (00:29:38) Starting... (30 nodes)	Bisected with a cut weight of 1210954.0 in 0.7864 secs.
# [R.W0.A.A.B.A.B.A] (00:29:39) Starting... (12 nodes)	Bisected with a cut weight of 1833416.0 in 0.8219 secs.
# [R.W0.A.A.B.A.B.A.A] (00:29:40) Starting... (5 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B.A.B.A.B] (00:29:40) Starting... (7 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B.A.B.B] (00:29:40) Starting... (18 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B.B]     (00:29:40) Starting... (40 nodes)	Bisected with a cut weight of 883474.0 in 0.9183 secs.
# [R.W0.A.A.B.B.A]   (00:29:41) Starting... (26 nodes)	Bisected with a cut weight of 1300690.0 in 0.8245 secs.
# [R.W0.A.A.B.B.A.A] (00:29:42) Starting... (14 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B.B.A.B] (00:29:42) Starting... (12 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B.B.B]   (00:29:42) Starting... (14 nodes)	Bisected with a cut weight of 219676.0 in 1.1696 secs.
# [R.W0.A.A.B.B.B.A] (00:29:43) Starting... (10 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B.B.B.B] (00:29:43) Starting... (4 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B]         (00:29:43) Starting... (111 nodes)	Bisected with a cut weight of 630309.0 in 2.6787 secs.
# [R.W0.A.B.A]       (00:29:46) Starting... (60 nodes)	Bisected with a cut weight of 464744.0 in 1.4245 secs.
# [R.W0.A.B.A.A]     (00:29:47) Starting... (36 nodes)	Bisected with a cut weight of 359697.0 in 1.5057 secs.
# [R.W0.A.B.A.A.A]   (00:29:49) Starting... (22 nodes)	Bisected with a cut weight of 258705.0 in 1.5445 secs.
# [R.W0.A.B.A.A.A.A] (00:29:50) Starting... (12 nodes)	Bisected with a cut weight of 163754.0 in 1.2173 secs.
# [R.W0.A.B.A.A.A.A.A] (00:29:51) Starting... (8 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.A.A.A.A.B] (00:29:51) Starting... (4 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.A.A.A.B] (00:29:51) Starting... (10 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.A.A.B]   (00:29:51) Starting... (14 nodes)	Bisected with a cut weight of 133468.0 in 0.8158 secs.
# [R.W0.A.B.A.A.B.A] (00:29:52) Starting... (9 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.A.A.B.B] (00:29:52) Starting... (5 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.A.B]     (00:29:52) Starting... (24 nodes)	Bisected with a cut weight of 172984.0 in 1.1969 secs.
# [R.W0.A.B.A.B.A]   (00:29:53) Starting... (14 nodes)	Bisected with a cut weight of 122293.0 in 1.2156 secs.
# [R.W0.A.B.A.B.A.A] (00:29:55) Starting... (8 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.A.B.A.B] (00:29:55) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.A.B.B]   (00:29:55) Starting... (10 nodes)	Bisected with a cut weight of 68623.0 in 1.0675 secs.
# [R.W0.A.B.A.B.B.A] (00:29:56) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.A.B.B.B] (00:29:56) Starting... (4 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.B]       (00:29:56) Starting... (51 nodes)	Bisected with a cut weight of 234655.0 in 1.8939 secs.
# [R.W0.A.B.B.A]     (00:29:57) Starting... (28 nodes)	Bisected with a cut weight of 156276.0 in 1.7481 secs.
# [R.W0.A.B.B.A.A]   (00:29:59) Starting... (18 nodes)	Bisected with a cut weight of 93243.0 in 1.3518 secs.
# [R.W0.A.B.B.A.A.A] (00:30:01) Starting... (9 nodes)	Bisected with a cut weight of 51778.0 in 1.0639 secs.
# [R.W0.A.B.B.A.A.A.A] (00:30:02) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.B.A.A.A.B] (00:30:02) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.B.A.A.B] (00:30:02) Starting... (9 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.B.A.B]   (00:30:02) Starting... (10 nodes)	Bisected with a cut weight of 71975.0 in 0.8474 secs.
# [R.W0.A.B.B.A.B.A] (00:30:03) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.B.A.B.B] (00:30:03) Starting... (4 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.B.B]     (00:30:03) Starting... (23 nodes)	Bisected with a cut weight of 95943.0 in 1.3066 secs.
# [R.W0.A.B.B.B.A]   (00:30:04) Starting... (10 nodes)	Bisected with a cut weight of 51879.0 in 1.1919 secs.
# [R.W0.A.B.B.B.A.A] (00:30:05) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.B.B.A.B] (00:30:05) Starting... (4 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.B.B.B]   (00:30:05) Starting... (13 nodes)	Aborted. Weight under threshold.
# [R.W0.B]           (00:30:05) Starting... (188 nodes)	Bisected with a cut weight of 312207.0 in 2.4942 secs.
# [R.W0.B.A]         (00:30:08) Starting... (105 nodes)	Bisected with a cut weight of 303216.0 in 2.2017 secs.
# [R.W0.B.A.A]       (00:30:10) Starting... (59 nodes)	Bisected with a cut weight of 236077.0 in 1.5629 secs.
# [R.W0.B.A.A.A]     (00:30:11) Starting... (30 nodes)	Bisected with a cut weight of 131101.0 in 1.1885 secs.
# [R.W0.B.A.A.A.A]   (00:30:13) Starting... (17 nodes)	Bisected with a cut weight of 121371.0 in 0.9637 secs.
# [R.W0.B.A.A.A.A.A] (00:30:13) Starting... (11 nodes)	Bisected with a cut weight of 65184.0 in 0.8875 secs.
# [R.W0.B.A.A.A.A.A.A] (00:30:14) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.A.A.A.A.B] (00:30:14) Starting... (5 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.A.A.A.B] (00:30:14) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.A.A.B]   (00:30:14) Starting... (13 nodes)	Bisected with a cut weight of 51974.0 in 1.1137 secs.
# [R.W0.B.A.A.A.B.A] (00:30:15) Starting... (8 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.A.A.B.B] (00:30:15) Starting... (5 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.A.B]     (00:30:15) Starting... (29 nodes)	Bisected with a cut weight of 105066.0 in 1.4641 secs.
# [R.W0.B.A.A.B.A]   (00:30:17) Starting... (19 nodes)	Bisected with a cut weight of 82183.0 in 1.1341 secs.
# [R.W0.B.A.A.B.A.A] (00:30:18) Starting... (8 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.A.B.A.B] (00:30:18) Starting... (11 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.A.B.B]   (00:30:18) Starting... (10 nodes)	Bisected with a cut weight of 34851.0 in 1.1619 secs.
# [R.W0.B.A.A.B.B.A] (00:30:19) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.A.B.B.B] (00:30:19) Starting... (4 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.B]       (00:30:19) Starting... (46 nodes)	Bisected with a cut weight of 113416.0 in 1.6153 secs.
# [R.W0.B.A.B.A]     (00:30:21) Starting... (27 nodes)	Bisected with a cut weight of 69178.0 in 1.3760 secs.
# [R.W0.B.A.B.A.A]   (00:30:22) Starting... (17 nodes)	Bisected with a cut weight of 47611.0 in 1.0883 secs.
# [R.W0.B.A.B.A.A.A] (00:30:23) Starting... (9 nodes)	Bisected with a cut weight of 22167.0 in 1.0454 secs.
# [R.W0.B.A.B.A.A.A.A] (00:30:24) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.B.A.A.A.B] (00:30:24) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.B.A.A.B] (00:30:24) Starting... (8 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.B.A.B]   (00:30:24) Starting... (10 nodes)	Bisected with a cut weight of 28218.0 in 1.0429 secs.
# [R.W0.B.A.B.A.B.A] (00:30:25) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.B.A.B.B] (00:30:25) Starting... (4 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.B.B]     (00:30:25) Starting... (19 nodes)	Bisected with a cut weight of 52942.0 in 1.1167 secs.
# [R.W0.B.A.B.B.A]   (00:30:27) Starting... (10 nodes)	Bisected with a cut weight of 33248.0 in 1.0931 secs.
# [R.W0.B.A.B.B.A.A] (00:30:28) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.B.B.A.B] (00:30:28) Starting... (4 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.B.B.B]   (00:30:28) Starting... (9 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B]         (00:30:28) Starting... (83 nodes)	Bisected with a cut weight of 89872.0 in 1.7347 secs.
# [R.W0.B.B.A]       (00:30:29) Starting... (46 nodes)	Bisected with a cut weight of 87389.0 in 2.1437 secs.
# [R.W0.B.B.A.A]     (00:30:32) Starting... (25 nodes)	Bisected with a cut weight of 68848.0 in 1.1711 secs.
# [R.W0.B.B.A.A.A]   (00:30:33) Starting... (15 nodes)	Bisected with a cut weight of 63850.0 in 1.1405 secs.
# [R.W0.B.B.A.A.A.A] (00:30:34) Starting... (9 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.A.A.A.B] (00:30:34) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.A.A.B]   (00:30:34) Starting... (10 nodes)	Bisected with a cut weight of 31523.0 in 1.0515 secs.
# [R.W0.B.B.A.A.B.A] (00:30:35) Starting... (5 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.A.A.B.B] (00:30:35) Starting... (5 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.A.B]     (00:30:35) Starting... (21 nodes)	Bisected with a cut weight of 35077.0 in 1.1444 secs.
# [R.W0.B.B.A.B.A]   (00:30:36) Starting... (11 nodes)	Bisected with a cut weight of 24908.0 in 1.2504 secs.
# [R.W0.B.B.A.B.A.A] (00:30:37) Starting... (5 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.A.B.A.B] (00:30:37) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.A.B.B]   (00:30:37) Starting... (10 nodes)	Bisected with a cut weight of 11491.0 in 1.0505 secs.
# [R.W0.B.B.A.B.B.A] (00:30:38) Starting... (7 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.A.B.B.B] (00:30:38) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.B]       (00:30:38) Starting... (37 nodes)	Bisected with a cut weight of 24576.0 in 1.2422 secs.
# [R.W0.B.B.B.A]     (00:30:40) Starting... (21 nodes)	Bisected with a cut weight of 26491.0 in 1.1133 secs.
# [R.W0.B.B.B.A.A]   (00:30:41) Starting... (12 nodes)	Bisected with a cut weight of 14203.0 in 1.1116 secs.
# [R.W0.B.B.B.A.A.A] (00:30:42) Starting... (8 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.B.A.A.B] (00:30:42) Starting... (4 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.B.A.B]   (00:30:42) Starting... (9 nodes)	Bisected with a cut weight of 8192.0 in 1.0993 secs.
# [R.W0.B.B.B.A.B.A] (00:30:43) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.B.A.B.B] (00:30:43) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.B.B]     (00:30:43) Starting... (16 nodes)	Bisected with a cut weight of 8192.0 in 1.1963 secs.
# [R.W0.B.B.B.B.A]   (00:30:44) Starting... (9 nodes)	Bisected with a cut weight of 4096.0 in 1.0268 secs.
# [R.W0.B.B.B.B.A.A] (00:30:45) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.B.B.A.B] (00:30:45) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.B.B.B]   (00:30:45) Starting... (7 nodes)	Aborted. Weight under threshold.
# [R.W1]             (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W2]             (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W3]             (00:30:45) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W4]             (00:30:45) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W5]             (00:30:45) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W6]             (00:30:45) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W7]             (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W8]             (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W9]             (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W10]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W11]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W12]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W13]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W14]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W15]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W16]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W17]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W18]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W19]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W20]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W21]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W22]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W23]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W24]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W25]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W26]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W27]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W28]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W29]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W30]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W31]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W32]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W33]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W34]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W35]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W36]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W37]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W38]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W39]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W40]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W41]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W42]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W43]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W44]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W45]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W46]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W47]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W48]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W49]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W50]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W51]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W52]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W53]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W54]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W55]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W56]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W57]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W58]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W59]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W60]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W61]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W62]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W63]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W64]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W65]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W66]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W67]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W68]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W69]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W70]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W71]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W72]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W73]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W74]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W75]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W76]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W77]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W78]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W79]            (00:30:45) Starting... (1 nodes)	Aborted. Weight under threshold.
# Running Akash19...
# DEBUG: best_k=2
# HERE
# Working on Subject #3: (logging-log4j2, log4j-api/src/main/java/org/apache/logging/log4j/spi/AbstractLogger.java)
# [R.W0]             (00:32:04) Starting... (2 nodes)	Aborted. Weight under threshold.
# [R.W1]             (00:32:04) Starting... (168 nodes)	Bisected with a cut weight of 139435.0 in 0.1045 secs.
# [R.W1.A]           (00:32:04) Starting... (103 nodes)	Bisected with a cut weight of 189983.0 in 0.0824 secs.
# [R.W1.A.A]         (00:32:04) Starting... (54 nodes)	Bisected with a cut weight of 91571.0 in 0.0636 secs.
# [R.W1.A.A.A]       (00:32:05) Starting... (11 nodes)	Aborted. Failed to partition.
# [R.W1.A.A.B]       (00:32:05) Starting... (43 nodes)	Aborted. Failed to partition.
# [R.W1.A.B]         (00:32:05) Starting... (49 nodes)	Bisected with a cut weight of 191334.0 in 0.0637 secs.
# [R.W1.A.B.A]       (00:32:05) Starting... (28 nodes)	Aborted. Failed to partition.
# [R.W1.A.B.B]       (00:32:05) Starting... (21 nodes)	Aborted. Failed to partition.
# [R.W1.B]           (00:32:05) Starting... (65 nodes)	Bisected with a cut weight of 168385.0 in 0.0775 secs.
# [R.W1.B.A]         (00:32:05) Starting... (23 nodes)	Bisected with a cut weight of 93668.0 in 0.0594 secs.
# [R.W1.B.A.A]       (00:32:05) Starting... (7 nodes)	Aborted. Failed to partition.
# [R.W1.B.A.B]       (00:32:05) Starting... (16 nodes)	Aborted. Failed to partition.
# [R.W1.B.B]         (00:32:05) Starting... (42 nodes)	Aborted. Failed to partition.
# [R.W2]             (00:32:05) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W3]             (00:32:05) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W4]             (00:32:05) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W5]             (00:32:05) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W6]             (00:32:05) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W7]             (00:32:05) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W8]             (00:32:05) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W9]             (00:32:05) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W10]            (00:32:05) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W11]            (00:32:05) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W12]            (00:32:05) Starting... (1 nodes)	Aborted. Weight under threshold.
# Running Akash19...
# DEBUG: best_k=3
# HERE
# Working on Subject #4: (activemq, activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java)
# [R.W0]             (00:33:57) Starting... (472 nodes)	Bisected with a cut weight of 493162.0 in 1.9019 secs.
# [R.W0.A]           (00:33:59) Starting... (347 nodes)	Bisected with a cut weight of 645370.0 in 1.7903 secs.
# [R.W0.A.A]         (00:34:00) Starting... (278 nodes)	Bisected with a cut weight of 380035.0 in 0.5533 secs.
# [R.W0.A.A.A]       (00:34:01) Starting... (220 nodes)	Bisected with a cut weight of 464788.0 in 0.6223 secs.
# [R.W0.A.A.A.A]     (00:34:02) Starting... (25 nodes)	Bisected with a cut weight of 105581.0 in 0.2165 secs.
# [R.W0.A.A.A.A.A]   (00:34:02) Starting... (10 nodes)	Bisected with a cut weight of 20480.0 in 0.1990 secs.
# [R.W0.A.A.A.A.A.A] (00:34:02) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.A.A.A.B] (00:34:02) Starting... (4 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.A.A.B]   (00:34:02) Starting... (15 nodes)	Bisected with a cut weight of 58229.0 in 0.2109 secs.
# [R.W0.A.A.A.A.B.A] (00:34:02) Starting... (5 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.A.A.B.B] (00:34:02) Starting... (10 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.A.B]     (00:34:02) Starting... (195 nodes)	Bisected with a cut weight of 457373.0 in 0.7680 secs.
# [R.W0.A.A.A.B.A]   (00:34:03) Starting... (174 nodes)	Bisected with a cut weight of 696274.0 in 0.6070 secs.
# [R.W0.A.A.A.B.A.A] (00:34:04) Starting... (164 nodes)	Bisected with a cut weight of 672075.0 in 0.4797 secs.
# [R.W0.A.A.A.B.A.A.A] (00:34:04) Starting... (25 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.A.B.A.A.B] (00:34:04) Starting... (139 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.A.B.A.B] (00:34:04) Starting... (10 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.A.B.B]   (00:34:04) Starting... (21 nodes)	Bisected with a cut weight of 102999.0 in 0.2583 secs.
# [R.W0.A.A.A.B.B.A] (00:34:04) Starting... (17 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.A.B.B.B] (00:34:04) Starting... (4 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B]       (00:34:04) Starting... (58 nodes)	Bisected with a cut weight of 139176.0 in 0.3656 secs.
# [R.W0.A.A.B.A]     (00:34:05) Starting... (41 nodes)	Bisected with a cut weight of 95062.0 in 0.3596 secs.
# [R.W0.A.A.B.A.A]   (00:34:05) Starting... (28 nodes)	Bisected with a cut weight of 56856.0 in 0.2164 secs.
# [R.W0.A.A.B.A.A.A] (00:34:05) Starting... (22 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B.A.A.B] (00:34:05) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B.A.B]   (00:34:05) Starting... (13 nodes)	Bisected with a cut weight of 32110.0 in 0.2085 secs.
# [R.W0.A.A.B.A.B.A] (00:34:06) Starting... (7 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B.A.B.B] (00:34:06) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B.B]     (00:34:06) Starting... (17 nodes)	Bisected with a cut weight of 57578.0 in 0.2168 secs.
# [R.W0.A.A.B.B.A]   (00:34:06) Starting... (9 nodes)	Bisected with a cut weight of 27445.0 in 0.2142 secs.
# [R.W0.A.A.B.B.A.A] (00:34:06) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B.B.A.B] (00:34:06) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B.B.B]   (00:34:06) Starting... (8 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B]         (00:34:06) Starting... (69 nodes)	Bisected with a cut weight of 337017.0 in 0.6820 secs.
# [R.W0.A.B.A]       (00:34:07) Starting... (40 nodes)	Bisected with a cut weight of 396728.0 in 0.5668 secs.
# [R.W0.A.B.A.A]     (00:34:07) Starting... (26 nodes)	Bisected with a cut weight of 230842.0 in 0.3530 secs.
# [R.W0.A.B.A.A.A]   (00:34:08) Starting... (10 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.A.A.B]   (00:34:08) Starting... (16 nodes)	Bisected with a cut weight of 242015.0 in 0.6464 secs.
# [R.W0.A.B.A.A.B.A] (00:34:08) Starting... (10 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.A.A.B.B] (00:34:08) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.A.B]     (00:34:08) Starting... (14 nodes)	Bisected with a cut weight of 204195.0 in 0.1722 secs.
# [R.W0.A.B.A.B.A]   (00:34:09) Starting... (7 nodes)	Bisected with a cut weight of 209429.0 in 0.6753 secs.
# [R.W0.A.B.A.B.A.A] (00:34:09) Starting... (4 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.A.B.A.B] (00:34:09) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.A.B.B]   (00:34:09) Starting... (7 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.B]       (00:34:09) Starting... (29 nodes)	Bisected with a cut weight of 104530.0 in 0.2959 secs.
# [R.W0.A.B.B.A]     (00:34:10) Starting... (17 nodes)	Bisected with a cut weight of 83521.0 in 0.2468 secs.
# [R.W0.A.B.B.A.A]   (00:34:10) Starting... (9 nodes)	Bisected with a cut weight of 66248.0 in 0.2167 secs.
# [R.W0.A.B.B.A.A.A] (00:34:10) Starting... (5 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.B.A.A.B] (00:34:10) Starting... (4 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.B.A.B]   (00:34:10) Starting... (8 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.B.B]     (00:34:10) Starting... (12 nodes)	Bisected with a cut weight of 44635.0 in 0.2157 secs.
# [R.W0.A.B.B.B.A]   (00:34:10) Starting... (7 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.B.B.B]   (00:34:10) Starting... (5 nodes)	Aborted. Weight under threshold.
# [R.W0.B]           (00:34:10) Starting... (125 nodes)	Bisected with a cut weight of 146297.0 in 0.7121 secs.
# [R.W0.B.A]         (00:34:11) Starting... (68 nodes)	Bisected with a cut weight of 132847.0 in 0.7007 secs.
# [R.W0.B.A.A]       (00:34:12) Starting... (37 nodes)	Bisected with a cut weight of 108726.0 in 0.4892 secs.
# [R.W0.B.A.A.A]     (00:34:12) Starting... (20 nodes)	Bisected with a cut weight of 80769.0 in 0.3594 secs.
# [R.W0.B.A.A.A.A]   (00:34:12) Starting... (12 nodes)	Bisected with a cut weight of 67700.0 in 0.2305 secs.
# [R.W0.B.A.A.A.A.A] (00:34:13) Starting... (7 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.A.A.A.B] (00:34:13) Starting... (5 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.A.A.B]   (00:34:13) Starting... (8 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.A.B]     (00:34:13) Starting... (17 nodes)	Bisected with a cut weight of 39093.0 in 0.2192 secs.
# [R.W0.B.A.A.B.A]   (00:34:13) Starting... (10 nodes)	Bisected with a cut weight of 33690.0 in 0.2191 secs.
# [R.W0.B.A.A.B.A.A] (00:34:13) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.A.B.A.B] (00:34:13) Starting... (4 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.A.B.B]   (00:34:13) Starting... (7 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.B]       (00:34:13) Starting... (31 nodes)	Bisected with a cut weight of 61965.0 in 0.4588 secs.
# [R.W0.B.A.B.A]     (00:34:14) Starting... (16 nodes)	Bisected with a cut weight of 27429.0 in 0.2098 secs.
# [R.W0.B.A.B.A.A]   (00:34:14) Starting... (9 nodes)	Bisected with a cut weight of 13332.0 in 0.2072 secs.
# [R.W0.B.A.B.A.A.A] (00:34:14) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.B.A.A.B] (00:34:14) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.B.A.B]   (00:34:14) Starting... (7 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.B.B]     (00:34:14) Starting... (15 nodes)	Bisected with a cut weight of 24576.0 in 0.2143 secs.
# [R.W0.B.A.B.B.A]   (00:34:14) Starting... (9 nodes)	Bisected with a cut weight of 12288.0 in 0.2126 secs.
# [R.W0.B.A.B.B.A.A] (00:34:14) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.B.B.A.B] (00:34:14) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.B.B.B]   (00:34:14) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B]         (00:34:14) Starting... (57 nodes)	Bisected with a cut weight of 57609.0 in 0.2984 secs.
# [R.W0.B.B.A]       (00:34:15) Starting... (29 nodes)	Bisected with a cut weight of 35437.0 in 0.2168 secs.
# [R.W0.B.B.A.A]     (00:34:15) Starting... (17 nodes)	Bisected with a cut weight of 27382.0 in 0.2256 secs.
# [R.W0.B.B.A.A.A]   (00:34:15) Starting... (9 nodes)	Bisected with a cut weight of 12013.0 in 0.2183 secs.
# [R.W0.B.B.A.A.A.A] (00:34:15) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.A.A.A.B] (00:34:15) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.A.A.B]   (00:34:15) Starting... (8 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.A.B]     (00:34:15) Starting... (12 nodes)	Bisected with a cut weight of 16384.0 in 0.2053 secs.
# [R.W0.B.B.A.B.A]   (00:34:16) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.A.B.B]   (00:34:16) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.B]       (00:34:16) Starting... (28 nodes)	Bisected with a cut weight of 20480.0 in 0.2184 secs.
# [R.W0.B.B.B.A]     (00:34:16) Starting... (16 nodes)	Bisected with a cut weight of 16384.0 in 0.2142 secs.
# [R.W0.B.B.B.A.A]   (00:34:16) Starting... (10 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.B.A.B]   (00:34:16) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.B.B]     (00:34:16) Starting... (12 nodes)	Bisected with a cut weight of 8192.0 in 0.2033 secs.
# [R.W0.B.B.B.B.A]   (00:34:16) Starting... (7 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.B.B.B]   (00:34:16) Starting... (5 nodes)	Aborted. Weight under threshold.
# [R.W1]             (00:34:16) Starting... (2 nodes)	Aborted. Weight under threshold.
# [R.W2]             (00:34:16) Starting... (2 nodes)	Aborted. Weight under threshold.
# [R.W3]             (00:34:16) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W4]             (00:34:16) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W5]             (00:34:16) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W6]             (00:34:16) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W7]             (00:34:16) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W8]             (00:34:16) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W9]             (00:34:16) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W10]            (00:34:16) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W11]            (00:34:16) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W12]            (00:34:16) Starting... (1 nodes)	Aborted. Weight under threshold.
# Running Akash19...
# DEBUG: best_k=2
# HERE
# Working on Subject #5: (activemq, activemq-broker/src/main/java/org/apache/activemq/broker/region/Queue.java)
# [R.W0]             (00:34:48) Starting... (128 nodes)	Bisected with a cut weight of 340420.0 in 0.4426 secs.
# [R.W0.A]           (00:34:48) Starting... (65 nodes)	Bisected with a cut weight of 338861.0 in 0.1628 secs.
# [R.W0.A.A]         (00:34:49) Starting... (32 nodes)	Bisected with a cut weight of 139989.0 in 0.1459 secs.
# [R.W0.A.A.A]       (00:34:49) Starting... (10 nodes)	Bisected with a cut weight of 46933.0 in 0.0509 secs.
# [R.W0.A.A.A.A]     (00:34:49) Starting... (5 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.A.B]     (00:34:49) Starting... (5 nodes)	Bisected with a cut weight of 38362.0 in 0.0504 secs.
# [R.W0.A.A.A.B.A]   (00:34:49) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.A.B.B]   (00:34:49) Starting... (2 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B]       (00:34:49) Starting... (22 nodes)	Bisected with a cut weight of 116165.0 in 0.0757 secs.
# [R.W0.A.A.B.A]     (00:34:49) Starting... (9 nodes)	Bisected with a cut weight of 47449.0 in 0.0553 secs.
# [R.W0.A.A.B.A.A]   (00:34:49) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B.A.B]   (00:34:49) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B.B]     (00:34:49) Starting... (13 nodes)	Bisected with a cut weight of 52893.0 in 0.0605 secs.
# [R.W0.A.A.B.B.A]   (00:34:49) Starting... (4 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B.B.B]   (00:34:49) Starting... (9 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B]         (00:34:49) Starting... (33 nodes)	Bisected with a cut weight of 407322.0 in 0.0731 secs.
# [R.W0.A.B.A]       (00:34:49) Starting... (13 nodes)	Bisected with a cut weight of 396544.0 in 0.0498 secs.
# [R.W0.A.B.A.A]     (00:34:49) Starting... (10 nodes)	Bisected with a cut weight of 93903.0 in 0.0490 secs.
# [R.W0.A.B.A.A.A]   (00:34:49) Starting... (4 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.A.A.B]   (00:34:49) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.A.B]     (00:34:49) Starting... (3 nodes)	Aborted. Failed to partition.
# [R.W0.A.B.B]       (00:34:49) Starting... (20 nodes)	Bisected with a cut weight of 229754.0 in 0.0668 secs.
# [R.W0.A.B.B.A]     (00:34:49) Starting... (11 nodes)	Bisected with a cut weight of 167643.0 in 0.0620 secs.
# [R.W0.A.B.B.A.A]   (00:34:49) Starting... (7 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.B.A.B]   (00:34:49) Starting... (4 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.B.B]     (00:34:49) Starting... (9 nodes)	Aborted. Weight under threshold.
# [R.W0.B]           (00:34:49) Starting... (63 nodes)	Bisected with a cut weight of 94094.0 in 0.2331 secs.
# [R.W0.B.A]         (00:34:50) Starting... (36 nodes)	Bisected with a cut weight of 90339.0 in 0.1289 secs.
# [R.W0.B.A.A]       (00:34:50) Starting... (21 nodes)	Bisected with a cut weight of 98462.0 in 0.0750 secs.
# [R.W0.B.A.A.A]     (00:34:50) Starting... (12 nodes)	Bisected with a cut weight of 93648.0 in 0.0651 secs.
# [R.W0.B.A.A.A.A]   (00:34:50) Starting... (8 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.A.A.B]   (00:34:50) Starting... (4 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.A.B]     (00:34:50) Starting... (9 nodes)	Bisected with a cut weight of 25592.0 in 0.0563 secs.
# [R.W0.B.A.A.B.A]   (00:34:50) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.A.B.B]   (00:34:50) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.B]       (00:34:50) Starting... (15 nodes)	Bisected with a cut weight of 32768.0 in 0.0605 secs.
# [R.W0.B.A.B.A]     (00:34:50) Starting... (9 nodes)	Bisected with a cut weight of 17811.0 in 0.0576 secs.
# [R.W0.B.A.B.A.A]   (00:34:50) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.B.A.B]   (00:34:50) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.B.B]     (00:34:50) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B]         (00:34:50) Starting... (27 nodes)	Bisected with a cut weight of 25212.0 in 0.0675 secs.
# [R.W0.B.B.A]       (00:34:50) Starting... (16 nodes)	Bisected with a cut weight of 24683.0 in 0.0584 secs.
# [R.W0.B.B.A.A]     (00:34:50) Starting... (9 nodes)	Bisected with a cut weight of 25402.0 in 0.0548 secs.
# [R.W0.B.B.A.A.A]   (00:34:50) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.A.A.B]   (00:34:50) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.A.B]     (00:34:50) Starting... (7 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.B]       (00:34:50) Starting... (11 nodes)	Bisected with a cut weight of 8192.0 in 0.0579 secs.
# [R.W0.B.B.B.A]     (00:34:50) Starting... (7 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.B.B]     (00:34:50) Starting... (4 nodes)	Aborted. Weight under threshold.
# [R.W1]             (00:34:50) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W2]             (00:34:50) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W3]             (00:34:50) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W4]             (00:34:50) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W5]             (00:34:50) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W6]             (00:34:50) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W7]             (00:34:50) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W8]             (00:34:50) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W9]             (00:34:50) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W10]            (00:34:50) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W11]            (00:34:50) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W12]            (00:34:50) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W13]            (00:34:50) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W14]            (00:34:50) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W15]            (00:34:50) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W16]            (00:34:50) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W17]            (00:34:50) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W18]            (00:34:50) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W19]            (00:34:50) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W20]            (00:34:50) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W21]            (00:34:50) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W22]            (00:34:50) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W23]            (00:34:50) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W24]            (00:34:50) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W25]            (00:34:50) Starting... (1 nodes)	Aborted. Weight under threshold.
# ...
# [R.W0.A.A.A.A.A]   (00:57:08) Starting... (14 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.A.A.B]   (00:57:08) Starting... (4 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.A.B]     (00:57:08) Starting... (8 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B]       (00:57:08) Starting... (12 nodes)	Bisected with a cut weight of 51847.0 in 0.0433 secs.
# [R.W0.A.A.B.A]     (00:57:08) Starting... (7 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B.B]     (00:57:08) Starting... (5 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B]         (00:57:08) Starting... (23 nodes)	Bisected with a cut weight of 69262.0 in 0.0619 secs.
# [R.W0.A.B.A]       (00:57:08) Starting... (14 nodes)	Bisected with a cut weight of 50261.0 in 0.0492 secs.
# [R.W0.A.B.A.A]     (00:57:08) Starting... (8 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.A.B]     (00:57:08) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.B]       (00:57:08) Starting... (9 nodes)	Bisected with a cut weight of 20110.0 in 0.0460 secs.
# [R.W0.A.B.B.A]     (00:57:08) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.B.B]     (00:57:08) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W0.B]           (00:57:08) Starting... (69 nodes)	Bisected with a cut weight of 32768.0 in 0.0869 secs.
# [R.W0.B.A]         (00:57:08) Starting... (50 nodes)	Bisected with a cut weight of 49152.0 in 0.0668 secs.
# [R.W0.B.A.A]       (00:57:08) Starting... (41 nodes)	Bisected with a cut weight of 8192.0 in 0.0526 secs.
# [R.W0.B.A.A.A]     (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.A.B]     (00:57:08) Starting... (40 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.B]       (00:57:08) Starting... (9 nodes)	Bisected with a cut weight of 8192.0 in 0.0447 secs.
# [R.W0.B.A.B.A]     (00:57:08) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.B.B]     (00:57:08) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B]         (00:57:08) Starting... (19 nodes)	Bisected with a cut weight of 12288.0 in 0.0482 secs.
# [R.W0.B.B.A]       (00:57:08) Starting... (9 nodes)	Bisected with a cut weight of 4096.0 in 0.0472 secs.
# [R.W0.B.B.A.A]     (00:57:08) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.A.B]     (00:57:08) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.B]       (00:57:08) Starting... (10 nodes)	Bisected with a cut weight of 4096.0 in 0.0453 secs.
# [R.W0.B.B.B.A]     (00:57:08) Starting... (7 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.B.B]     (00:57:08) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W1]             (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W2]             (00:57:08) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W3]             (00:57:08) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W4]             (00:57:08) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W5]             (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W6]             (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W7]             (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W8]             (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W9]             (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W10]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W11]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W12]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W13]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W14]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W15]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W16]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W17]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W18]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W19]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W20]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W21]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W22]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W23]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W24]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W25]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W26]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W27]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W28]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W29]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W30]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W31]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W32]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W33]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W34]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W35]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W36]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W37]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W38]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W39]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W40]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W41]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W42]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W43]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W44]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W45]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W46]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W47]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W48]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W49]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W50]            (00:57:08) Starting... (1 nodes)	Aborted. Weight under threshold.
# Running Akash19...
# DEBUG: best_k=2
# HERE
# Working on Subject #157: (activemq, activemq-broker/src/main/java/org/apache/activemq/broker/jmx/BrokerView.java)
# [R.W0]             (00:57:16) Starting... (187 nodes)	Bisected with a cut weight of 84888.0 in 0.1260 secs.
# [R.W0.A]           (00:57:16) Starting... (141 nodes)	Bisected with a cut weight of 196190.0 in 0.1252 secs.
# [R.W0.A.A]         (00:57:16) Starting... (42 nodes)	Bisected with a cut weight of 166470.0 in 0.0759 secs.
# [R.W0.A.A.A]       (00:57:17) Starting... (15 nodes)	Bisected with a cut weight of 151748.0 in 0.0536 secs.
# [R.W0.A.A.A.A]     (00:57:17) Starting... (5 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.A.B]     (00:57:17) Starting... (10 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B]       (00:57:17) Starting... (27 nodes)	Bisected with a cut weight of 164201.0 in 0.0583 secs.
# [R.W0.A.A.B.A]     (00:57:17) Starting... (22 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B.B]     (00:57:17) Starting... (5 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B]         (00:57:17) Starting... (99 nodes)	Bisected with a cut weight of 199826.0 in 0.1196 secs.
# [R.W0.A.B.A]       (00:57:17) Starting... (81 nodes)	Bisected with a cut weight of 223081.0 in 0.0990 secs.
# [R.W0.A.B.A.A]     (00:57:17) Starting... (55 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.A.B]     (00:57:17) Starting... (26 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.B]       (00:57:17) Starting... (18 nodes)	Bisected with a cut weight of 43094.0 in 0.0598 secs.
# [R.W0.A.B.B.A]     (00:57:17) Starting... (5 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.B.B]     (00:57:17) Starting... (13 nodes)	Aborted. Weight under threshold.
# [R.W0.B]           (00:57:17) Starting... (46 nodes)	Bisected with a cut weight of 63310.0 in 0.0793 secs.
# [R.W0.B.A]         (00:57:17) Starting... (19 nodes)	Bisected with a cut weight of 21746.0 in 0.0619 secs.
# [R.W0.B.A.A]       (00:57:17) Starting... (9 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.B]       (00:57:17) Starting... (10 nodes)	Bisected with a cut weight of 12288.0 in 0.0630 secs.
# [R.W0.B.A.B.A]     (00:57:17) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.B.B]     (00:57:17) Starting... (7 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B]         (00:57:17) Starting... (27 nodes)	Bisected with a cut weight of 46792.0 in 0.0644 secs.
# [R.W0.B.B.A]       (00:57:17) Starting... (11 nodes)	Bisected with a cut weight of 19206.0 in 0.0583 secs.
# [R.W0.B.B.A.A]     (00:57:17) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.A.B]     (00:57:17) Starting... (8 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.B]       (00:57:17) Starting... (16 nodes)	Bisected with a cut weight of 31402.0 in 0.0609 secs.
# [R.W0.B.B.B.A]     (00:57:17) Starting... (5 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.B.B]     (00:57:17) Starting... (11 nodes)	Aborted. Weight under threshold.
# [R.W1]             (00:57:17) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W2]             (00:57:17) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W3]             (00:57:17) Starting... (2 nodes)	Aborted. Weight under threshold.
# [R.W4]             (00:57:17) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W5]             (00:57:17) Starting... (1 nodes)	Aborted. Weight under threshold.
# Running Akash19...
# DEBUG: best_k=2
# HERE
# Working on Subject #158: (logging-log4j2, log4j-api/src/main/java/org/apache/logging/log4j/message/StructuredDataMessage.java)
# [R.W0]             (00:57:24) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W1]             (00:57:24) Starting... (35 nodes)	Bisected with a cut weight of 19536.0 in 0.0302 secs.
# [R.W1.A]           (00:57:24) Starting... (5 nodes)	Bisected with a cut weight of 4096.0 in 0.0121 secs.
# [R.W1.A.A]         (00:57:24) Starting... (2 nodes)	Aborted. Failed to partition.
# [R.W1.A.B]         (00:57:24) Starting... (3 nodes)	Aborted. Failed to partition.
# [R.W1.B]           (00:57:24) Starting... (30 nodes)	Bisected with a cut weight of 25559.0 in 0.0201 secs.
# [R.W1.B.A]         (00:57:24) Starting... (19 nodes)	Bisected with a cut weight of 50745.0 in 0.0133 secs.
# [R.W1.B.A.A]       (00:57:24) Starting... (8 nodes)	Bisected with a cut weight of 17585.0 in 0.0091 secs.
# [R.W1.B.A.A.A]     (00:57:24) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W1.B.A.A.B]     (00:57:24) Starting... (5 nodes)	Aborted. Weight under threshold.
# [R.W1.B.A.B]       (00:57:24) Starting... (11 nodes)	Aborted. Weight under threshold.
# [R.W1.B.B]         (00:57:24) Starting... (11 nodes)	Bisected with a cut weight of 17716.0 in 0.0135 secs.
# [R.W1.B.B.A]       (00:57:24) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W1.B.B.B]       (00:57:24) Starting... (8 nodes)	Aborted. Weight under threshold.
# [R.W2]             (00:57:24) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W3]             (00:57:24) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W4]             (00:57:24) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W5]             (00:57:24) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W6]             (00:57:24) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W7]             (00:57:24) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W8]             (00:57:24) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W9]             (00:57:24) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W10]            (00:57:24) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W11]            (00:57:24) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W12]            (00:57:24) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W13]            (00:57:24) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W14]            (00:57:24) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W15]            (00:57:24) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W16]            (00:57:24) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W17]            (00:57:24) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W18]            (00:57:24) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W19]            (00:57:24) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W20]            (00:57:24) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W21]            (00:57:24) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W22]            (00:57:24) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W23]            (00:57:24) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W24]            (00:57:24) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W25]            (00:57:24) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W26]            (00:57:24) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W27]            (00:57:24) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W28]            (00:57:24) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W29]            (00:57:24) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W30]            (00:57:24) Starting... (1 nodes)	Aborted. Weight under threshold.
# Running Akash19...
# DEBUG: best_k=2
# HERE
# Working on Subject #159: (pinot, pinot-segment-spi/src/main/java/org/apache/pinot/segment/spi/creator/IndexCreationContext.java)
# [R.W0]             (00:57:31) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W1]             (00:57:31) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W2]             (00:57:31) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W3]             (00:57:31) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W4]             (00:57:31) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W5]             (00:57:31) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W6]             (00:57:31) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W7]             (00:57:31) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W8]             (00:57:31) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W9]             (00:57:31) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W10]            (00:57:31) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W11]            (00:57:31) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W12]            (00:57:31) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W13]            (00:57:31) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W14]            (00:57:31) Starting... (33 nodes)	Bisected with a cut weight of 36864.0 in 0.0190 secs.
# [R.W14.A]          (00:57:31) Starting... (13 nodes)	Aborted. Weight under threshold.
# [R.W14.B]          (00:57:31) Starting... (20 nodes)	Aborted. Weight under threshold.
# ['activemq', 'calcite', 'dubbo', 'hudi', 'iotdb', 'kafka', 'logging-log4j2', 'nifi', 'pinot', 'shenyu']
