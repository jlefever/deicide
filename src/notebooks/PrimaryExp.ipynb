# %%
import sys
import os

import pandas as pd

sys.path.append("..")
from deicide import jdeo, gri
from deicide.validation2 import *
from deicide.loading import load_dataset, load_full_candidates_df
from deicide.deicide import cluster_dataset
from deicide.dendrogram import dump_indicators

# %%
import warnings
warnings.simplefilter(action="ignore", category=pd.errors.PerformanceWarning)

# %%
def validate_subjects(
    subjects: pd.DataFrame, db_dir: str, jd_dir: str, results_dir: str, suffix: str
):
    if os.path.exists(results_dir):
        raise RuntimeError("the results dir '{}' already exists".format(results_dir))
    os.makedirs(results_dir)

    res = subjects.copy()
    res["my_blocks"] = ""
    res["unmatched_jd_methods"] = ""
    res["comparable_methods"] = ""
    res["comparable_commits"] = ""
    res["comparable_authors"] = ""
    res["my_comparable_clusters"] = ""
    res["jd_comparable_clusters"] = ""
    res["my_commit_sim"] = ""
    res["jd_commit_sim"] = ""
    res["my_author_sim"] = ""
    res["jd_author_sim"] = ""

    for i, (subject_id, row) in enumerate(subjects.iterrows()):
        project = row["project"]
        filename = row["filename"]
        print("Working on Subject #{}: ({}, {})".format(i + 1, project, filename))

        # Define helper function for setting output values
        def set_cell(col_name, value):
            res.at[subject_id, col_name] = value

        # Load JD clustering
        jd_rows = jdeo.load_jdeo_subject(jd_dir, project, filename)

        # Skip if not in JD data
        if len(jd_rows) == 0:
            print("Missing from JD. Skipping...")
            continue

        # Run our clustering algorithm
        ds = load_dataset(f"{db_dir}{project}.db", filename, row["commit_id"])
        entities_df = cluster_dataset(ds)
        targets_df = entities_df[~(entities_df["kind"] == "file")]
        # entities_df.to_csv(os.path.join(results_dir, "{}.csv".format(subject_id)))
        set_cell("my_blocks", targets_df.groupby("block_name").ngroups)

        # Attempt to match JD entity data with ours
        jd_id_map = jdeo.match_entities(jd_rows, ds.targets_df)
        unmatched_jd_methods = sum(
            1 for row, id in jd_id_map.items() if id is None and row.kind == "method"
        )
        set_cell("unmatched_jd_methods", unmatched_jd_methods)

        if unmatched_jd_methods > 2:
            continue

        # Create clustering objects for each kind of clustering
        my_clustering = to_my_clustering(entities_df).without_root()
        jd_clustering = to_jdeo_clustering(jd_id_map).without_root()
        commit_clustering = to_commit_clustering(ds.touches_df)
        author_clustering = to_author_clustering(ds.touches_df)

        # Get methods in common
        method_ids = set(entities_df[entities_df["kind"] == "method"].index)
        my_entity_ids = my_clustering.entities()
        jd_entity_ids = jd_clustering.entities()
        commit_entity_ids = commit_clustering.entities()
        author_entity_ids = author_clustering.entities()
        common_method_ids = (
            method_ids
            & my_entity_ids
            & jd_entity_ids
            & commit_entity_ids
            & author_entity_ids
        )

        # For debug / diagram purposes
        # client_clustering = to_client_clustering(ds.clients_df, ds.client_deps_df).subset(common_method_ids)
        my_clustering_with_files = to_my_clustering_with_files(entities_df).without_root()

        # ...
        my_subclustering = my_clustering.subset(common_method_ids)
        jd_subclustering = jd_clustering.subset(common_method_ids)
        commit_subclustering = commit_clustering.subset(common_method_ids)
        author_subclustering = author_clustering.subset(common_method_ids)

        # Remove any cluster that 1) contains only a single entity AND 2) is not that entities only cluster
        my_subclustering = my_subclustering.normalize()
        jd_subclustering = jd_subclustering.normalize()

        # Dump
        dump_indicators(
            entities_df.copy(),
            os.path.join(results_dir, f"{subject_id}.xlsx"),
            my_clx=my_clustering,
            # my_clx_without_singletons=my_clustering.normalize(),
            # my_clx_final=my_subclustering,
            # my_clx_with_files = my_clustering_with_files,
            # jd_clx=jd_clustering,
            # jd_clx_without_singletons=jd_clustering.normalize(),
            # jd_clx_final=jd_subclustering,
            # commit_clx=commit_clustering,
            # author_clx=author_clustering,
            # client_clx=client_clustering
        )

        # Create matrices from each kind of clustering
        my_arr = my_subclustering.expand().ndarray()
        jd_arr = jd_subclustering.expand().ndarray()
        commit_arr = commit_subclustering.ndarray()
        author_arr = author_subclustering.ndarray()

        # Record the sizes of these matrices
        set_cell("comparable_methods", len(common_method_ids))
        set_cell("comparable_commits", commit_arr.shape[0])
        set_cell("comparable_authors", author_arr.shape[0])
        set_cell("my_comparable_clusters", my_arr.shape[0])
        set_cell("jd_comparable_clusters", jd_arr.shape[0])

        # Calculate the similarities
        set_cell("my_commit_sim", gri.grand_index(my_arr, commit_arr))
        set_cell("jd_commit_sim", gri.grand_index(jd_arr, commit_arr))
        set_cell("my_author_sim", gri.grand_index(my_arr, author_arr))
        set_cell("jd_author_sim", gri.grand_index(jd_arr, author_arr))

    print(sorted(set(res["project"])))

    # Unable to match more than two methods reported by JD to our data.
    # One cause of this is that JD will list members of nested classes as
    # members of the top level class. Wheras we only consider members
    # directly inside the top-level class.
    res = res[res["unmatched_jd_methods"] < 3]
    res["short_filename"] = [f.split("/")[-1] for f in res["filename"]]
    res.to_csv(os.path.join(results_dir, f"_summary{suffix}.csv"))

# %%
RESULTS_DIR = "results/"
DB_DIR = "data-db/"
JD_DIR = "data-jd/"

# %%
# Discover subjects
cdf = load_full_candidates_df(DB_DIR, JD_DIR)
subjects_df = cdf[(cdf["loc_pct"] >= 90) & (cdf["loc"] >= 500) & (cdf["commits"] >= 10) & (cdf["authors"] >= 2) & cdf["in_jdeo_data"]].copy()
# Out:
# Finding candidates in activemq.db...
# Finding candidates in calcite.db...
# Finding candidates in camel.db...
# Finding candidates in dolphinscheduler.db...
# Finding candidates in drill.db...
# Finding candidates in dubbo.db...
# Finding candidates in hudi.db...
# Finding candidates in ignite.db...
# Finding candidates in iotdb.db...
# Finding candidates in kafka.db...
# Finding candidates in linkis.db...
# Finding candidates in logging-log4j2.db...
# Finding candidates in nifi.db...
# Finding candidates in pinot.db...
# Finding candidates in pulsar.db...
# Finding candidates in shardingsphere.db...
# Finding candidates in shenyu.db...

# %%
# Drop some less important columns to produce an easier to read CSV
labels = [c for c in subjects_df.columns if c.endswith("_pct")] + ["in_jdeo_data"]
subjects_df.drop(labels, axis=1, inplace=True)

# %%
subjects_df
# Out:
#                             project  commit_id  \
# id
# pinot-947                     pinot       2379
# logging-log4j2-3381  logging-log4j2        960
# iotdb-2037                    iotdb       4105
# shenyu-1385                  shenyu       1853
# dubbo-198                     dubbo       1499
# ...                             ...        ...
# pinot-11553                   pinot       2379
# iotdb-16992                   iotdb       4105
# pinot-3741                    pinot       2379
# pinot-2448                    pinot       2379
# dubbo-4994                    dubbo       1499
#
#                                                               filename   loc  \
# id
# pinot-947            pinot-controller/src/main/java/org/apache/pino...  3633
# logging-log4j2-3381  log4j-api/src/main/java/org/apache/logging/log...  2848
# iotdb-2037           tsfile/src/main/java/org/apache/iotdb/tsfile/r...  2148
# shenyu-1385          shenyu-common/src/main/java/org/apache/shenyu/...  1745
# dubbo-198            dubbo-common/src/main/java/org/apache/dubbo/co...  1686
# ...                                                                ...   ...
# pinot-11553          pinot-controller/src/main/java/org/apache/pino...   523
# iotdb-16992          schema-engine-tag/src/main/java/org/apache/iot...   517
# pinot-3741           pinot-spi/src/main/java/org/apache/pinot/spi/d...   513
# pinot-2448           pinot-server/src/main/java/org/apache/pinot/se...   513
# dubbo-4994           dubbo-common/src/main/java/org/apache/dubbo/co...   506
#
#                      members  fan_in  commits  churn  authors
# id
# pinot-947                212     110      122  11630       36
# logging-log4j2-3381      474     112       15   2478        6
# iotdb-2037               103      96       77  10973       23
# shenyu-1385               64      25       27   7749        8
# dubbo-198                231     884       39  17144       13
# ...                      ...     ...      ...    ...      ...
# pinot-11553               38       4       10   2417        6
# iotdb-16992               57       1       23   4003        6
# pinot-3741                58     618       24   1284       12
# pinot-2448                38       1       38   1875       15
# dubbo-4994               103      88       18    495        6
#
# [74 rows x 9 columns]

# %%
# Get the result_dir
os.makedirs(RESULTS_DIR, exist_ok=True)
result_nums = [int(n.split("-")[1]) for n in os.listdir(RESULTS_DIR) if n.startswith("results-")]
result_num = max(result_nums, default=0) + 1
result_dir = os.path.join(RESULTS_DIR, f"results-{result_num}")

# %%
validate_subjects(subjects_df, DB_DIR, JD_DIR, result_dir, f"-{result_num}")
# Out:
# Working on Subject #1: (pinot, pinot-controller/src/main/java/org/apache/pinot/controller/helix/core/PinotHelixResourceManager.java)
# [R.W0]             (20:00:21) Starting... (299 nodes)	Bisected with a cut weight of 1006090.0 in 10.2063 secs.
# [R.W0.A]           (20:00:31) Starting... (198 nodes)	Bisected with a cut weight of 916935.0 in 6.1858 secs.
# [R.W0.A.A]         (20:00:37) Starting... (84 nodes)	Bisected with a cut weight of 341525.0 in 0.4343 secs.
# [R.W0.A.A.A]       (20:00:38) Starting... (30 nodes)	Bisected with a cut weight of 123794.0 in 0.1931 secs.
# [R.W0.A.A.A.A]     (20:00:38) Starting... (10 nodes)	Bisected with a cut weight of 41064.0 in 0.1756 secs.
# [R.W0.A.A.A.A.A]   (20:00:38) Starting... (7 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.A.A.B]   (20:00:38) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.A.B]     (20:00:38) Starting... (20 nodes)	Bisected with a cut weight of 72914.0 in 0.1716 secs.
# [R.W0.A.A.A.B.A]   (20:00:38) Starting... (9 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.A.B.B]   (20:00:38) Starting... (11 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B]       (20:00:38) Starting... (54 nodes)	Bisected with a cut weight of 291442.0 in 0.2360 secs.
# [R.W0.A.A.B.A]     (20:00:39) Starting... (18 nodes)	Bisected with a cut weight of 197647.0 in 0.2159 secs.
# [R.W0.A.A.B.A.A]   (20:00:39) Starting... (14 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B.A.B]   (20:00:39) Starting... (4 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B.B]     (20:00:39) Starting... (36 nodes)	Bisected with a cut weight of 321280.0 in 0.4582 secs.
# [R.W0.A.A.B.B.A]   (20:00:39) Starting... (13 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B.B.B]   (20:00:39) Starting... (23 nodes)	Bisected with a cut weight of 345975.0 in 0.1957 secs.
# [R.W0.A.A.B.B.B.A] (20:00:39) Starting... (12 nodes)	Aborted. Weight under threshold.
# [R.W0.A.A.B.B.B.B] (20:00:39) Starting... (11 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B]         (20:00:39) Starting... (114 nodes)	Bisected with a cut weight of 856391.0 in 3.5800 secs.
# [R.W0.A.B.A]       (20:00:43) Starting... (40 nodes)	Bisected with a cut weight of 447839.0 in 0.4527 secs.
# [R.W0.A.B.A.A]     (20:00:44) Starting... (17 nodes)	Bisected with a cut weight of 185333.0 in 0.2014 secs.
# [R.W0.A.B.A.A.A]   (20:00:44) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.A.A.B]   (20:00:44) Starting... (11 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.A.B]     (20:00:44) Starting... (23 nodes)	Bisected with a cut weight of 482678.0 in 0.4034 secs.
# [R.W0.A.B.A.B.A]   (20:00:44) Starting... (13 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.A.B.B]   (20:00:44) Starting... (10 nodes)	Bisected with a cut weight of 420240.0 in 0.2300 secs.
# [R.W0.A.B.A.B.B.A] (20:00:44) Starting... (7 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.A.B.B.B] (20:00:44) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.B]       (20:00:44) Starting... (74 nodes)	Bisected with a cut weight of 813913.0 in 1.4181 secs.
# [R.W0.A.B.B.A]     (20:00:46) Starting... (49 nodes)	Bisected with a cut weight of 535051.0 in 0.4458 secs.
# [R.W0.A.B.B.A.A]   (20:00:46) Starting... (35 nodes)	Bisected with a cut weight of 197066.0 in 0.1964 secs.
# [R.W0.A.B.B.A.A.A] (20:00:46) Starting... (5 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.B.A.A.B] (20:00:46) Starting... (30 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.B.A.B]   (20:00:46) Starting... (14 nodes)	Bisected with a cut weight of 297832.0 in 0.3284 secs.
# [R.W0.A.B.B.A.B.A] (20:00:47) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.B.A.B.B] (20:00:47) Starting... (8 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.B.B]     (20:00:47) Starting... (25 nodes)	Bisected with a cut weight of 382315.0 in 0.2569 secs.
# [R.W0.A.B.B.B.A]   (20:00:47) Starting... (17 nodes)	Bisected with a cut weight of 245000.0 in 0.2362 secs.
# [R.W0.A.B.B.B.A.A] (20:00:47) Starting... (14 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.B.B.A.B] (20:00:47) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W0.A.B.B.B.B]   (20:00:47) Starting... (8 nodes)	Aborted. Weight under threshold.
# [R.W0.B]           (20:00:47) Starting... (101 nodes)	Bisected with a cut weight of 540826.0 in 2.1930 secs.
# [R.W0.B.A]         (20:00:49) Starting... (60 nodes)	Bisected with a cut weight of 571024.0 in 1.8244 secs.
# [R.W0.B.A.A]       (20:00:51) Starting... (25 nodes)	Bisected with a cut weight of 220043.0 in 0.2437 secs.
# [R.W0.B.A.A.A]     (20:00:52) Starting... (9 nodes)	Bisected with a cut weight of 124204.0 in 0.1670 secs.
# [R.W0.B.A.A.A.A]   (20:00:52) Starting... (3 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.A.A.B]   (20:00:52) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.A.B]     (20:00:52) Starting... (16 nodes)	Bisected with a cut weight of 306208.0 in 0.2897 secs.
# [R.W0.B.A.A.B.A]   (20:00:52) Starting... (8 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.A.B.B]   (20:00:52) Starting... (8 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.B]       (20:00:52) Starting... (35 nodes)	Bisected with a cut weight of 441379.0 in 0.6452 secs.
# [R.W0.B.A.B.A]     (20:00:53) Starting... (22 nodes)	Bisected with a cut weight of 408656.0 in 0.4785 secs.
# [R.W0.B.A.B.A.A]   (20:00:53) Starting... (12 nodes)	Bisected with a cut weight of 306616.0 in 0.2369 secs.
# [R.W0.B.A.B.A.A.A] (20:00:53) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.B.A.A.B] (20:00:53) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.B.A.B]   (20:00:53) Starting... (10 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.B.B]     (20:00:53) Starting... (13 nodes)	Bisected with a cut weight of 199466.0 in 0.2361 secs.
# [R.W0.B.A.B.B.A]   (20:00:54) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.B.A.B.B.B]   (20:00:54) Starting... (7 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B]         (20:00:54) Starting... (41 nodes)	Bisected with a cut weight of 118858.0 in 0.4643 secs.
# [R.W0.B.B.A]       (20:00:54) Starting... (23 nodes)	Bisected with a cut weight of 128230.0 in 0.1954 secs.
# [R.W0.B.B.A.A]     (20:00:54) Starting... (13 nodes)	Bisected with a cut weight of 231771.0 in 0.2601 secs.
# [R.W0.B.B.A.A.A]   (20:00:55) Starting... (5 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.A.A.B]   (20:00:55) Starting... (8 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.A.B]     (20:00:55) Starting... (10 nodes)	Bisected with a cut weight of 32692.0 in 0.1720 secs.
# [R.W0.B.B.A.B.A]   (20:00:55) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.A.B.B]   (20:00:55) Starting... (4 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.B]       (20:00:55) Starting... (18 nodes)	Bisected with a cut weight of 31539.0 in 0.1658 secs.
# [R.W0.B.B.B.A]     (20:00:55) Starting... (11 nodes)	Bisected with a cut weight of 34892.0 in 0.1633 secs.
# [R.W0.B.B.B.A.A]   (20:00:55) Starting... (5 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.B.A.B]   (20:00:55) Starting... (6 nodes)	Aborted. Weight under threshold.
# [R.W0.B.B.B.B]     (20:00:55) Starting... (7 nodes)	Aborted. Weight under threshold.
# [R.W1]             (20:00:55) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W2]             (20:00:55) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W3]             (20:00:55) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W4]             (20:00:55) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W5]             (20:00:55) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W6]             (20:00:55) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W7]             (20:00:55) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W8]             (20:00:55) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W9]             (20:00:55) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W10]            (20:00:55) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W11]            (20:00:55) Starting... (1 nodes)	Aborted. Weight under threshold.
# [R.W12]            (20:00:55) Starting... (1 nodes)	Aborted. Weight under threshold.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/source/python/deicide/.venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 31758
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/jtl86/source/python/deicide/src/notebooks/PrimaryExp.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell:/Users/jtl86/source/python/deicide/src/notebooks/PrimaryExp.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> validate_subjects(subjects_df, DB_DIR, JD_DIR, result_dir, f"-{result_num}")
#
# /Users/jtl86/source/python/deicide/src/notebooks/PrimaryExp.ipynb Cell 9 line 9
#      <a href='vscode-notebook-cell:/Users/jtl86/source/python/deicide/src/notebooks/PrimaryExp.ipynb#X11sZmlsZQ%3D%3D?line=86'>87</a> jd_subclustering = jd_subclustering.normalize()
#      <a href='vscode-notebook-cell:/Users/jtl86/source/python/deicide/src/notebooks/PrimaryExp.ipynb#X11sZmlsZQ%3D%3D?line=88'>89</a> # Dump
# ---> <a href='vscode-notebook-cell:/Users/jtl86/source/python/deicide/src/notebooks/PrimaryExp.ipynb#X11sZmlsZQ%3D%3D?line=89'>90</a> dump_indicators(
#      <a href='vscode-notebook-cell:/Users/jtl86/source/python/deicide/src/notebooks/PrimaryExp.ipynb#X11sZmlsZQ%3D%3D?line=90'>91</a>     entities_df.copy(),
#      <a href='vscode-notebook-cell:/Users/jtl86/source/python/deicide/src/notebooks/PrimaryExp.ipynb#X11sZmlsZQ%3D%3D?line=91'>92</a>     os.path.join(results_dir, f"{subject_id}.xlsx"),
#      <a href='vscode-notebook-cell:/Users/jtl86/source/python/deicide/src/notebooks/PrimaryExp.ipynb#X11sZmlsZQ%3D%3D?line=92'>93</a>     my_clx=my_clustering,
#      <a href='vscode-notebook-cell:/Users/jtl86/source/python/deicide/src/notebooks/PrimaryExp.ipynb#X11sZmlsZQ%3D%3D?line=93'>94</a>     my_clx_without_singletons=my_clustering.normalize(),
#      <a href='vscode-notebook-cell:/Users/jtl86/source/python/deicide/src/notebooks/PrimaryExp.ipynb#X11sZmlsZQ%3D%3D?line=94'>95</a>     my_clx_final=my_subclustering,
#      <a href='vscode-notebook-cell:/Users/jtl86/source/python/deicide/src/notebooks/PrimaryExp.ipynb#X11sZmlsZQ%3D%3D?line=95'>96</a>     my_clx_with_files = my_clustering_with_files,
#      <a href='vscode-notebook-cell:/Users/jtl86/source/python/deicide/src/notebooks/PrimaryExp.ipynb#X11sZmlsZQ%3D%3D?line=96'>97</a>     jd_clx=jd_clustering,
#      <a href='vscode-notebook-cell:/Users/jtl86/source/python/deicide/src/notebooks/PrimaryExp.ipynb#X11sZmlsZQ%3D%3D?line=97'>98</a>     jd_clx_without_singletons=jd_clustering.normalize(),
#      <a href='vscode-notebook-cell:/Users/jtl86/source/python/deicide/src/notebooks/PrimaryExp.ipynb#X11sZmlsZQ%3D%3D?line=98'>99</a>     jd_clx_final=jd_subclustering,
#     <a href='vscode-notebook-cell:/Users/jtl86/source/python/deicide/src/notebooks/PrimaryExp.ipynb#X11sZmlsZQ%3D%3D?line=99'>100</a>     commit_clx=commit_clustering,
#     <a href='vscode-notebook-cell:/Users/jtl86/source/python/deicide/src/notebooks/PrimaryExp.ipynb#X11sZmlsZQ%3D%3D?line=100'>101</a>     author_clx=author_clustering,
#     <a href='vscode-notebook-cell:/Users/jtl86/source/python/deicide/src/notebooks/PrimaryExp.ipynb#X11sZmlsZQ%3D%3D?line=101'>102</a>     # client_clx=client_clustering
#     <a href='vscode-notebook-cell:/Users/jtl86/source/python/deicide/src/notebooks/PrimaryExp.ipynb#X11sZmlsZQ%3D%3D?line=102'>103</a> )
#     <a href='vscode-notebook-cell:/Users/jtl86/source/python/deicide/src/notebooks/PrimaryExp.ipynb#X11sZmlsZQ%3D%3D?line=104'>105</a> # Create matrices from each kind of clustering
#     <a href='vscode-notebook-cell:/Users/jtl86/source/python/deicide/src/notebooks/PrimaryExp.ipynb#X11sZmlsZQ%3D%3D?line=105'>106</a> my_arr = my_subclustering.expand().ndarray()
#
# File ~/source/python/deicide/src/deicide/dendrogram.py:157, in dump_indicators(entities_df, path, **kwargs)
#     155 for name, clustering in kwargs.items():
#     156     wb.create_sheet(name)
# --> 157     add_clustering(wb[name], clustering, sort_entities, get_name)
#     159 del wb["Sheet"]
#     160 wb.save(path)
#
# File ~/source/python/deicide/src/deicide/dendrogram.py:140, in add_clustering(ws, clustering, sort_entities, get_name)
#     138 merge_header_cells(ws, merges)
#     139 delta_i = mat.shape[0]
# --> 140 entity_ids = sort_entities(filled_clustering.entities())
#     141 for i, entity_id in enumerate(entity_ids):
#     142     ws.cell(delta_i + i + 1, 1, get_name(entity_id))
#
# File ~/source/python/deicide/src/deicide/dendrogram.py:149, in dump_indicators.<locals>.sort_entities(entitiy_ids)
#     148 def sort_entities(entitiy_ids: set[int]) -> list[int]:
# --> 149     return sorted(entitiy_ids, key=lambda id: entities_df.loc[id]["start_row"])
#
# File ~/source/python/deicide/src/deicide/dendrogram.py:149, in dump_indicators.<locals>.sort_entities.<locals>.<lambda>(id)
#     148 def sort_entities(entitiy_ids: set[int]) -> list[int]:
# --> 149     return sorted(entitiy_ids, key=lambda id: entities_df.loc[id]["start_row"])
#
# File ~/source/python/deicide/.venv/lib/python3.11/site-packages/pandas/core/indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/source/python/deicide/.venv/lib/python3.11/site-packages/pandas/core/indexing.py:1393, in _LocIndexer._getitem_axis(self, key, axis)
#    1391 # fall thru to straight lookup
#    1392 self._validate_key(key, axis)
# -> 1393 return self._get_label(key, axis=axis)
#
# File ~/source/python/deicide/.venv/lib/python3.11/site-packages/pandas/core/indexing.py:1343, in _LocIndexer._get_label(self, label, axis)
#    1341 def _get_label(self, label, axis: AxisInt):
#    1342     # GH#5567 this will fail if the label is not present in the axis.
# -> 1343     return self.obj.xs(label, axis=axis)
#
# File ~/source/python/deicide/.venv/lib/python3.11/site-packages/pandas/core/generic.py:4236, in NDFrame.xs(self, key, axis, level, drop_level)
#    4234             new_index = index[loc]
#    4235 else:
# -> 4236     loc = index.get_loc(key)
#    4238     if isinstance(loc, np.ndarray):
#    4239         if loc.dtype == np.bool_:
#
# File ~/source/python/deicide/.venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 31758
