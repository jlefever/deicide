# %%
from deicide.loading import load_dataset, fetch_latest_commit_id

# %%
DB_PATH = "data/dubbo.db"
FILENAME = "dubbo-common/src/main/java/org/apache/dubbo/common/utils/UrlUtils.java"
COMMIT_ID = fetch_latest_commit_id(DB_PATH)
DS = load_dataset(DB_PATH, FILENAME, COMMIT_ID)

# %%
DS.targets_df
# Out:
#         parent_id                                 name         kind  \
# id
# 76043        5319                             UrlUtils  constructor
# 97060        5319            URL_PARAM_STARTING_SYMBOL        field
# 5320         5319                             parseURL       method
# 48492        5319                            parseURLs       method
# 72858        5319                      convertRegister       method
# 72861        5319                     convertSubscribe       method
# 72862        5319                       revertRegister       method
# 72857        5319                      revertSubscribe       method
# 72860        5319                         revertNotify       method
# 38042        5319                         revertForbid       method
# 45484        5319                          getEmptyUrl       method
# 45483        5319                      isMatchCategory       method
# 45488        5319                              isMatch       method
# ...
